# %%
import json

id2label = {
    0: "B-LOC",
    1: "B-MISC",
    2: "B-ORG",
    3: "B-PER",
    4: "I-LOC",
    5: "I-MISC",
    6: "I-ORG",
    7: "I-PER",
    8: "O"
}

def load(path):
    return [json.loads(line) for line in open(path, "r", encoding="utf8")]

def extract_spans(tokens, tags):
    spans = []
    current = None

    for i, tag_id in enumerate(tags):
        tag = id2label[tag_id]

        if tag == "O":
            if current:
                spans.append(current)
                current = None
            continue

        prefix, label = tag.split("-")

        if prefix == "B":
            if current:
                spans.append(current)
            current = {"label": label, "start": i, "end": i+1}

        elif prefix == "I":
            if current and current["label"] == label:
                current["end"] = i+1
            else:
                # I-X without matching B-X → treat as new entity
                current = {"label": label, "start": i, "end": i+1}

    if current:
        spans.append(current)

    # Convert to readable form
    readable = []
    for s in spans:
        text = " ".join(tokens[s["start"]:s["end"]])
        readable.append((s["label"], text))
    return readable
disagree = []
def analyze(a1, a2, a3):
    A = load(a1)
    B = load(a2)
    C = load(a3)
    base = load("test_pred_base.jsonl")
    bertweet = load("bertweet_pred.jsonl")
    gold = load("test.jsonl")

    for idx, (x, y, z,b,btweet,g) in enumerate(zip(A, B, C,base,bertweet,gold)):
        spansA = extract_spans(x["tokens"], x["tags"])
        spansB = extract_spans(y["tokens"], y["tags"])
        spansC = extract_spans(z["tokens"], z["tags"])
        spans_base = extract_spans(b["tokens"],b["tags"])
        spans_bertweet = extract_spans(btweet["tokens"],btweet["tags"])
        spans_gold = extract_spans(g["tokens"],g["tags"])

        if not (spansA == spansB == spansC):
            disagree.append(idx)
            print("="*80)
            print(f"TWEET {idx}")
            print("TOKENS:", " ".join(x["tokens"]))
            print()
            print("Annotator A:", spansA)
            print("Annotator B:", spansB)
            print("Annotator C:", spansC)
            print("Baseline:", spans_base)
            print("Bertweet:", spans_bertweet)
            print("Gold standard", spans_gold)
            print()

# Example:
analyze("val_500.jsonl", "Hjalte_500.jsonl", "mar_500.jsonl")
print(disagree)
# Out:
# ================================================================================
# TWEET 6
# TOKENS: RT @USER445 : Spine - Chilling Stories of Real Life Cannibals , Horrible ! URL1310 URL1455
#
# Annotator A: []
# Annotator B: []
# Annotator C: [('MISC', 'Spine')]
# Baseline: []
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 7
# TOKENS: I 've entered for a chance to win a copy of @USER1136 on XB1 from @USER1071 thanks to @USER718 ! Enter HERE : URL1617
#
# Annotator A: [('MISC', 'XB1')]
# Annotator B: [('ORG', 'XB1')]
# Annotator C: [('ORG', 'XB1')]
# Baseline: []
# Bertweet: [('MISC', 'XB1')]
# Gold standard []
#
# ================================================================================
# TWEET 11
# TOKENS: RT @USER487 : Where is AKMU Where is MADE full album Where is EXIT : X Where is YGGG Saddest ? Where is Minzy ?
#
# Annotator A: [('MISC', 'AKMU'), ('MISC', 'MADE'), ('MISC', 'EXIT'), ('MISC', 'YGGG Saddest'), ('PER', 'Minzy')]
# Annotator B: [('MISC', 'AKMU'), ('MISC', 'MADE'), ('MISC', 'EXIT'), ('MISC', 'YGGG'), ('PER', 'Minzy')]
# Annotator C: [('PER', 'AKMU'), ('PER', 'Minzy')]
# Baseline: [('ORG', 'AKMU'), ('MISC', 'MADE'), ('PER', 'YGGG'), ('PER', 'Minzy')]
# Bertweet: [('ORG', 'AKMU'), ('ORG', 'MADE'), ('PER', 'YGGG'), ('PER', 'Minzy')]
# Gold standard [('ORG', 'AKMU'), ('ORG', 'MADE'), ('ORG', 'EXIT'), ('ORG', 'YGGG Saddest'), ('PER', 'Minzy')]
#
# ================================================================================
# TWEET 12
# TOKENS: RT @USER2437 : If you have short memory let me inform you after signing COD Benazir made infamous NRO deal with Mushi . ☺ URL224 …
#
# Annotator A: [('MISC', 'COD'), ('PER', 'Benazir'), ('MISC', 'NRO'), ('PER', 'Mushi')]
# Annotator B: [('PER', 'Benazir'), ('PER', 'Mushi')]
# Annotator C: [('MISC', 'COD Benazir'), ('PER', 'with'), ('PER', 'Mushi')]
# Baseline: [('PER', 'COD'), ('PER', 'Benazir'), ('MISC', 'NRO'), ('PER', 'Mushi')]
# Bertweet: [('PER', 'Benazir'), ('PER', 'Mushi')]
# Gold standard [('PER', 'Benazir'), ('ORG', 'NRO'), ('PER', 'Mushi')]
#
# ================================================================================
# TWEET 15
# TOKENS: Get Weather Updates from theweatherchannel 10:56:06
#
# Annotator A: []
# Annotator B: [('ORG', 'theweatherchannel')]
# Annotator C: [('ORG', 'theweatherchannel')]
# Baseline: [('ORG', 'theweatherchannel')]
# Bertweet: [('ORG', 'theweatherchannel')]
# Gold standard [('ORG', 'theweatherchannel')]
#
# ================================================================================
# TWEET 18
# TOKENS: #NowPlaying Get Another Boyfriend of @USER1659
#
# Annotator A: [('MISC', 'Get Another Boyfriend')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: [('MISC', 'Another Boyfriend')]
# Gold standard [('MISC', 'Get Another Boyfriend')]
#
# ================================================================================
# TWEET 19
# TOKENS: #baseball Bengie Molina considers retirement after World Series URL87
#
# Annotator A: [('PER', 'Bengie Molina'), ('MISC', 'World Series')]
# Annotator B: [('PER', 'Bengie Molina')]
# Annotator C: [('PER', 'Bengie Molina'), ('MISC', 'World Series')]
# Baseline: [('PER', 'Bengie Molina'), ('MISC', 'World Series')]
# Bertweet: [('PER', 'Bengie Molina'), ('MISC', 'World Series')]
# Gold standard [('PER', 'Bengie Molina'), ('MISC', 'World Series')]
#
# ================================================================================
# TWEET 20
# TOKENS: #championLife RT @USER2393 : Lakers game wo n't start until they get those rings right ? See you at 10:45
#
# Annotator A: [('ORG', 'Lakers')]
# Annotator B: [('ORG', 'Lakers')]
# Annotator C: [('MISC', 'Lakers')]
# Baseline: [('ORG', 'Lakers')]
# Bertweet: [('ORG', 'Lakers')]
# Gold standard [('ORG', 'Lakers')]
#
# ================================================================================
# TWEET 22
# TOKENS: #nothappy that Adelaide has lost the #rugbysevens
#
# Annotator A: [('ORG', 'Adelaide')]
# Annotator B: [('PER', 'Adelaide')]
# Annotator C: [('LOC', 'Adelaide')]
# Baseline: [('ORG', 'Adelaide')]
# Bertweet: [('LOC', 'Adelaide')]
# Gold standard [('ORG', 'Adelaide')]
#
# ================================================================================
# TWEET 23
# TOKENS: . @USER1012 & I are talking about optics entrepreneurship & " the Actuality story " tonight Media Lab E14 - 525 6 p - 8 p for URL51
#
# Annotator A: [('MISC', 'Media Lab E14')]
# Annotator B: [('ORG', 'Media Lab')]
# Annotator C: [('ORG', 'Media Lab')]
# Baseline: [('MISC', 'optics'), ('ORG', 'Lab')]
# Bertweet: [('ORG', 'Media Lab')]
# Gold standard [('MISC', 'the Actuality story'), ('ORG', 'Media Lab')]
#
# ================================================================================
# TWEET 24
# TOKENS: 1 , 2 , 3 , 4 , 5 Teen Titans !
#
# Annotator A: [('ORG', 'Teen Titans')]
# Annotator B: [('MISC', 'Teen Titans')]
# Annotator C: [('MISC', 'Teen Titans')]
# Baseline: [('MISC', '!')]
# Bertweet: [('MISC', 'Teen Titans')]
# Gold standard [('MISC', 'Teen Titans')]
#
# ================================================================================
# TWEET 26
# TOKENS: @ troy smith is about to finish the rest of the season for the 49ers ... he 's gon na get them a win this week
#
# Annotator A: [('PER', 'troy smith'), ('ORG', '49ers')]
# Annotator B: [('PER', 'troy smith'), ('ORG', '49ers')]
# Annotator C: [('PER', 'troy smith')]
# Baseline: [('PER', 'troy smith'), ('ORG', '49ers')]
# Bertweet: [('PER', 'troy smith'), ('ORG', '49ers')]
# Gold standard [('PER', 'troy smith'), ('ORG', '49ers')]
#
# ================================================================================
# TWEET 27
# TOKENS: @USER90 NBC is going to have the NYC fireworks on . They are amazing - at least in person they were two years ago .
#
# Annotator A: [('ORG', 'NBC'), ('LOC', 'NYC')]
# Annotator B: [('ORG', 'NBC'), ('LOC', 'NYC')]
# Annotator C: [('ORG', '@USER90'), ('ORG', 'NBC'), ('LOC', 'NYC')]
# Baseline: [('ORG', 'NBC'), ('LOC', 'NYC')]
# Bertweet: [('ORG', 'NBC'), ('LOC', 'NYC')]
# Gold standard [('ORG', 'NBC'), ('LOC', 'NYC')]
#
# ================================================================================
# TWEET 28
# TOKENS: @USER153 I 'm scoopin Jo right now
#
# Annotator A: [('PER', 'Jo')]
# Annotator B: [('PER', 'Jo')]
# Annotator C: []
# Baseline: [('PER', 'Jo')]
# Bertweet: [('PER', 'Jo')]
# Gold standard [('PER', 'Jo')]
#
# ================================================================================
# TWEET 43
# TOKENS: @USER771 that 's ladybug
#
# Annotator A: []
# Annotator B: [('PER', 'ladybug')]
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 50
# TOKENS: @USER1039 benadryl is your friend lol
#
# Annotator A: [('PER', 'benadryl')]
# Annotator B: []
# Annotator C: [('MISC', 'benadryl')]
# Baseline: [('PER', 'benadryl')]
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 54
# TOKENS: @USER1163 haha u wish ! Just wait for me to fins a cool name tht has darren + loewe in it lol ( everything sounds bad :( )
#
# Annotator A: []
# Annotator B: [('PER', 'darren'), ('PER', 'loewe')]
# Annotator C: [('PER', 'darren'), ('PER', 'loewe')]
# Baseline: []
# Bertweet: [('PER', 'darren'), ('PER', 'loewe')]
# Gold standard [('PER', 'darren'), ('PER', 'loewe')]
#
# ================================================================================
# TWEET 61
# TOKENS: @USER1439 I 'M on east coast and their on . do n't know how that works live in CA. ? WITWIAL
#
# Annotator A: [('LOC', 'CA.'), ('LOC', 'WITWIAL')]
# Annotator B: [('LOC', 'east coast'), ('LOC', 'CA.')]
# Annotator C: [('LOC', 'CA.')]
# Baseline: [('LOC', 'east'), ('LOC', 'coast'), ('LOC', 'CA.')]
# Bertweet: [('LOC', 'CA.')]
# Gold standard [('LOC', 'east coast'), ('LOC', 'CA.')]
#
# ================================================================================
# TWEET 66
# TOKENS: @USER1602 @USER1512 I uploaded / uploading remaining albums . Muackszx
#
# Annotator A: []
# Annotator B: [('MISC', 'Muackszx')]
# Annotator C: []
# Baseline: [('PER', 'Muackszx')]
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 68
# TOKENS: @USER1651 with there boycotts and the way they betrayed the country in ww1 they were right in there assessment
#
# Annotator A: [('MISC', 'ww1')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: [('MISC', 'ww1')]
# Gold standard []
#
# ================================================================================
# TWEET 81
# TOKENS: @USER2243 noo ... Sostar !!!!
#
# Annotator A: [('PER', 'Sostar')]
# Annotator B: [('MISC', 'Sostar')]
# Annotator C: []
# Baseline: [('MISC', 'Sostar')]
# Bertweet: [('ORG', 'Sostar')]
# Gold standard []
#
# ================================================================================
# TWEET 84
# TOKENS: @USER2337 Talking points ? #RobFord has a new idea to bring to City of Toronto politics : saving money instead of wasting it . #voteto
#
# Annotator A: [('ORG', 'City of Toronto politics')]
# Annotator B: [('LOC', 'City of Toronto')]
# Annotator C: []
# Baseline: [('ORG', 'City of'), ('LOC', 'Toronto')]
# Bertweet: [('LOC', 'of'), ('LOC', 'Toronto')]
# Gold standard [('LOC', 'Toronto')]
#
# ================================================================================
# TWEET 85
# TOKENS: @USER2503 Reportedly Testing All - Dorito Taco Shell URL204
#
# Annotator A: [('MISC', 'Dorito'), ('MISC', 'Taco'), ('MISC', 'Shell')]
# Annotator B: []
# Annotator C: []
# Baseline: [('MISC', 'Dorito'), ('MISC', 'Taco Shell')]
# Bertweet: [('ORG', 'Dorito')]
# Gold standard [('ORG', 'Dorito')]
#
# ================================================================================
# TWEET 90
# TOKENS: Amateur Radio – Hurricane Katrina interview and audio | Survival Kits URL49
#
# Annotator A: [('ORG', 'Amateur Radio'), ('MISC', 'Hurricane Katrina'), ('MISC', 'Survival Kits')]
# Annotator B: [('PER', 'Hurricane Katrina')]
# Annotator C: [('ORG', 'Amateur Radio')]
# Baseline: [('MISC', 'Hurricane Katrina')]
# Bertweet: [('MISC', 'Hurricane Katrina')]
# Gold standard [('MISC', 'Hurricane Katrina')]
#
# ================================================================================
# TWEET 91
# TOKENS: Ambitious young Italians are quitting their country in droves , leaving power in the hands of an elderly elite . URL111 #tsunami
#
# Annotator A: [('MISC', 'Italians')]
# Annotator B: []
# Annotator C: []
# Baseline: [('MISC', 'Italians')]
# Bertweet: [('MISC', 'Italians')]
# Gold standard [('MISC', 'Italians')]
#
# ================================================================================
# TWEET 94
# TOKENS: Check out Cooking How - To : Homemade Frisco Melts on Tales of a midwestern Housewife ! URL15
#
# Annotator A: [('MISC', 'Cooking How - To'), ('MISC', 'Frisco')]
# Annotator B: []
# Annotator C: []
# Baseline: [('MISC', 'Frisco')]
# Bertweet: [('MISC', 'Frisco')]
# Gold standard []
#
# ================================================================================
# TWEET 95
# TOKENS: Cut it out joey ... * talkin to myself *
#
# Annotator A: [('PER', 'joey')]
# Annotator B: [('PER', 'joey')]
# Annotator C: [('PER', 'out'), ('PER', 'joey')]
# Baseline: []
# Bertweet: [('PER', 'joey')]
# Gold standard [('PER', 'joey')]
#
# ================================================================================
# TWEET 96
# TOKENS: Deputy pulls over FL man , naked teen in backseat ... URL201 #fl #florida #oops #dumb #sex #dui #traffic #news #police
#
# Annotator A: [('LOC', 'FL')]
# Annotator B: []
# Annotator C: [('LOC', 'FL')]
# Baseline: []
# Bertweet: [('LOC', 'FL')]
# Gold standard [('LOC', 'FL')]
#
# ================================================================================
# TWEET 98
# TOKENS: Does it feel like Summer to you ? It does in Myrtle Beach , South Carolina it s 85 degrees
#
# Annotator A: [('LOC', 'Myrtle Beach , South Carolina')]
# Annotator B: [('LOC', 'Myrtle Beach'), ('LOC', 'South Carolina')]
# Annotator C: [('LOC', 'Myrtle Beach'), ('LOC', ','), ('LOC', 'South Carolina')]
# Baseline: [('LOC', 'Myrtle'), ('LOC', 'Beach'), ('LOC', 'South'), ('LOC', 'Carolina')]
# Bertweet: [('LOC', 'Myrtle Beach'), ('LOC', 'South Carolina')]
# Gold standard [('LOC', 'Myrtle Beach'), ('LOC', 'South Carolina')]
#
# ================================================================================
# TWEET 99
# TOKENS: Excellent article about Intelligent Management founder Lepore inspired by Jewish philosophy to find business solutions URL48
#
# Annotator A: [('ORG', 'Intelligent Management'), ('PER', 'Lepore'), ('MISC', 'Jewish')]
# Annotator B: [('ORG', 'Intelligent Management'), ('PER', 'Lepore')]
# Annotator C: []
# Baseline: [('MISC', 'Management'), ('PER', 'Lepore'), ('MISC', 'Jewish')]
# Bertweet: [('MISC', 'Intelligent Management'), ('PER', 'Lepore'), ('MISC', 'Jewish')]
# Gold standard [('ORG', 'Intelligent Management'), ('PER', 'Lepore'), ('MISC', 'Jewish')]
#
# ================================================================================
# TWEET 100
# TOKENS: Excited for rough cut screening of @USER2147 tonight . Then season premier of Friday Night Lights at the Man-sion . Yessirr .
#
# Annotator A: [('MISC', 'Friday Night Lights at the Man-sion')]
# Annotator B: [('MISC', 'Friday Night Lights')]
# Annotator C: []
# Baseline: [('MISC', 'Friday Night Lights'), ('MISC', 'Man-sion')]
# Bertweet: [('MISC', 'Friday Night Lights'), ('MISC', 'Man-sion')]
# Gold standard [('MISC', 'Friday Night Lights'), ('LOC', 'Man-sion')]
#
# ================================================================================
# TWEET 106
# TOKENS: Great Gizmos Indoor Garden Green Pots ( Green ) £ 13.94 [ SAVE £ 6.05 ] >> URL13 #bargains #deals 10.27.10
#
# Annotator A: [('MISC', 'Great Gizmos Indoor Garden Green Pots')]
# Annotator B: [('ORG', 'Great Gizmos')]
# Annotator C: []
# Baseline: [('ORG', 'Gizmos')]
# Bertweet: []
# Gold standard [('ORG', 'Great Gizmos')]
#
# ================================================================================
# TWEET 107
# TOKENS: Guess Who " American Woman "
#
# Annotator A: [('MISC', 'American')]
# Annotator B: []
# Annotator C: []
# Baseline: [('MISC', 'Guess'), ('MISC', 'American Woman')]
# Bertweet: [('MISC', 'American Woman')]
# Gold standard [('ORG', 'Guess Who'), ('MISC', 'American Woman')]
#
# ================================================================================
# TWEET 111
# TOKENS: Happy Guys Finish Last - EmpowHER.com URL156 vía @USER1854
#
# Annotator A: []
# Annotator B: []
# Annotator C: [('ORG', 'EmpowHER.com')]
# Baseline: [('ORG', 'EmpowHER.com')]
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 112
# TOKENS: Happy Main Event Day ! GL to all who are playing on Day 1A . Action begins at 3 ET .
#
# Annotator A: [('MISC', 'Main Event Day')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 117
# TOKENS: I 'm at Mr. Mikes . URL8
#
# Annotator A: [('PER', 'Mr. Mikes')]
# Annotator B: [('PER', 'Mr. Mikes')]
# Annotator C: [('LOC', 'Mr. Mikes')]
# Baseline: [('MISC', 'Mikes')]
# Bertweet: [('PER', 'Mikes')]
# Gold standard []
#
# ================================================================================
# TWEET 118
# TOKENS: I 'm at Scopa ( 109A Plaza St. , Healdsburg Ave. , Healdsburg ) . URL5
#
# Annotator A: [('MISC', 'Scopa'), ('LOC', '109A Plaza St. , Healdsburg Ave. , Healdsburg')]
# Annotator B: [('LOC', '109A Plaza St.'), ('LOC', 'Healdsburg Ave.'), ('LOC', 'Healdsburg')]
# Annotator C: [('LOC', 'Scopa ( 109A Plaza St.'), ('LOC', 'Healdsburg Ave.'), ('LOC', 'Healdsburg')]
# Baseline: [('LOC', 'Scopa'), ('MISC', 'St.'), ('MISC', 'Ave.'), ('LOC', 'Healdsburg')]
# Bertweet: [('MISC', 'Scopa'), ('LOC', '109A Plaza St.'), ('LOC', 'Healdsburg Ave.'), ('LOC', 'Healdsburg')]
# Gold standard [('LOC', 'Scopa'), ('LOC', '109A Plaza St. , Healdsburg Ave. , Healdsburg')]
#
# ================================================================================
# TWEET 125
# TOKENS: I forgot just how good Molson Golden truly is ...... Thanks TIm O
#
# Annotator A: [('MISC', 'Molson Golden')]
# Annotator B: [('PER', 'Molson Golden'), ('PER', 'TIm O')]
# Annotator C: [('PER', 'Molson Golden'), ('PER', 'TIm')]
# Baseline: [('MISC', 'Golden')]
# Bertweet: [('PER', 'Molson Golden')]
# Gold standard [('ORG', 'Molson Golden')]
#
# ================================================================================
# TWEET 130
# TOKENS: I think jawn was tryna be smart talk'n bout da baul little do she know I d nt give two shits about none of these Cheyney boy 's .
#
# Annotator A: [('PER', 'jawn'), ('LOC', 'Cheyney')]
# Annotator B: [('PER', 'jawn'), ('LOC', 'Cheyney')]
# Annotator C: []
# Baseline: [('PER', 'Cheyney')]
# Bertweet: [('MISC', 'Cheyney')]
# Gold standard []
#
# ================================================================================
# TWEET 132
# TOKENS: I want Brazilian food
#
# Annotator A: [('MISC', 'Brazilian')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: [('MISC', 'Brazilian')]
# Gold standard [('MISC', 'Brazilian')]
#
# ================================================================================
# TWEET 133
# TOKENS: If you can see only one Darfur documentary this year , I recommend The Devil Came on Horseback . URL2
#
# Annotator A: [('LOC', 'Darfur'), ('MISC', 'The Devil Came on Horseback')]
# Annotator B: [('PER', 'Darfur'), ('MISC', 'The Devil Came on Horseback')]
# Annotator C: []
# Baseline: [('LOC', 'Darfur'), ('MISC', 'The Devil Came on')]
# Bertweet: [('LOC', 'Darfur'), ('MISC', 'The Devil Came on Horseback')]
# Gold standard [('LOC', 'Darfur'), ('MISC', 'The Devil Came on Horseback')]
#
# ================================================================================
# TWEET 137
# TOKENS: Lol welcome to Twitter @USER2290
#
# Annotator A: [('ORG', 'Twitter')]
# Annotator B: []
# Annotator C: [('ORG', 'Twitter')]
# Baseline: [('ORG', 'Twitter')]
# Bertweet: [('ORG', 'Twitter')]
# Gold standard [('ORG', 'Twitter')]
#
# ================================================================================
# TWEET 144
# TOKENS: New NC Highway Signs Welcome Motorists To " Most Military Friendly State " : New signs going up on the major highways ... URL37
#
# Annotator A: [('LOC', 'NC')]
# Annotator B: [('LOC', 'NC')]
# Annotator C: [('ORG', 'NC Highway Signs'), ('ORG', 'Motorists')]
# Baseline: [('LOC', 'NC')]
# Bertweet: [('LOC', 'NC')]
# Gold standard [('LOC', 'NC')]
#
# ================================================================================
# TWEET 146
# TOKENS: Northrop Grumman 3Q profit rises , boosts forecast ( AP ) : AP - Defense contractor Northrop Grumman Corp. say ... URL24
#
# Annotator A: [('ORG', 'Northrop Grumman'), ('ORG', 'Northrop Grumman Corp.')]
# Annotator B: [('PER', 'Northrop'), ('PER', 'Grumman'), ('ORG', 'Northrop Grumman Corp.')]
# Annotator C: [('ORG', 'Northrop Grumman'), ('ORG', 'Northrop Grumman Corp.')]
# Baseline: [('ORG', 'Northrop Grumman'), ('ORG', 'AP'), ('ORG', 'Defense'), ('ORG', 'Northrop Grumman Corp.')]
# Bertweet: [('ORG', 'Northrop Grumman'), ('ORG', 'Defense'), ('ORG', 'Northrop Grumman Corp.')]
# Gold standard [('ORG', 'Northrop Grumman'), ('ORG', 'Northrop Grumman Corp.')]
#
# ================================================================================
# TWEET 148
# TOKENS: On eve of UFC debut , James Toney learned of IRS lien , fight purse withheld URL177
#
# Annotator A: [('ORG', 'UFC'), ('PER', 'James Toney'), ('ORG', 'IRS')]
# Annotator B: [('ORG', 'UFC'), ('PER', 'James Toney'), ('PER', 'IRS lien')]
# Annotator C: [('ORG', 'UFC'), ('PER', 'James Toney')]
# Baseline: [('MISC', 'UFC'), ('PER', 'James Toney')]
# Bertweet: [('ORG', 'UFC'), ('PER', 'James Toney'), ('ORG', 'IRS')]
# Gold standard [('ORG', 'UFC'), ('PER', 'James Toney'), ('ORG', 'IRS')]
#
# ================================================================================
# TWEET 153
# TOKENS: Pretty simple actually . - The DataContext will tunnel down to controls below it in the tree . - The ListBox ... URL31 #WPF #2010
#
# Annotator A: []
# Annotator B: []
# Annotator C: [('MISC', 'DataContext')]
# Baseline: [('MISC', 'DataContext'), ('MISC', 'The'), ('MISC', 'ListBox')]
# Bertweet: [('MISC', 'DataContext')]
# Gold standard []
#
# ================================================================================
# TWEET 154
# TOKENS: Public and private jobs | Angry Bear : The wife and I used to work retail for the California State Parks . If our pa ... URL18
#
# Annotator A: [('ORG', 'California State Parks')]
# Annotator B: [('MISC', 'Angry Bear'), ('LOC', 'California State')]
# Annotator C: []
# Baseline: [('MISC', 'Bear'), ('ORG', 'State Parks')]
# Bertweet: [('LOC', 'California State Parks')]
# Gold standard [('PER', 'Angry Bear'), ('ORG', 'California State Parks')]
#
# ================================================================================
# TWEET 166
# TOKENS: RT @USER1135 : Billionaires / CEOs throwing massive $$$ into front Orgs since Citizens United . They plan to BUY America Gov't in 201 ...
#
# Annotator A: [('ORG', "America Gov't")]
# Annotator B: [('ORG', 'Citizens United'), ('LOC', 'America')]
# Annotator C: []
# Baseline: [('ORG', 'Citizens United'), ('MISC', 'America')]
# Bertweet: [('MISC', 'Citizens United'), ('MISC', 'America')]
# Gold standard [('ORG', 'Citizens United'), ('MISC', 'America')]
#
# ================================================================================
# TWEET 168
# TOKENS: RT @USER1226 : @USER1642 lol you know i m down like 4 flats on a cadillac ... lol wut it do ?? || Haha ! love it
#
# Annotator A: []
# Annotator B: [('ORG', 'cadillac')]
# Annotator C: []
# Baseline: []
# Bertweet: [('MISC', 'cadillac')]
# Gold standard []
#
# ================================================================================
# TWEET 175
# TOKENS: RT @USER1818 : Home Opener is 2 days away . Need a costume ? 1st 5000 fans get a Halloween black & orange @USER146 yth jersey URL0 ...
#
# Annotator A: [('MISC', 'Halloween')]
# Annotator B: [('MISC', 'Home Opener')]
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard [('MISC', 'Halloween')]
#
# ================================================================================
# TWEET 181
# TOKENS: Security Clearance | Systems Admin - Integrated Exploitation Capability ( IEC ) - Lentech , Inc. - St .... URL25 #missouri #jobs
#
# Annotator A: [('ORG', 'Lentech')]
# Annotator B: [('ORG', 'Lentech , Inc.')]
# Annotator C: [('ORG', 'Lentech , Inc.')]
# Baseline: [('ORG', 'Lentech'), ('ORG', 'Inc.'), ('LOC', 'St'), ('LOC', '....')]
# Bertweet: [('ORG', 'Lentech'), ('ORG', 'Inc.')]
# Gold standard [('ORG', 'Lentech'), ('ORG', 'Inc.')]
#
# ================================================================================
# TWEET 185
# TOKENS: TCA to play for Colorado 3A women 's soccer championship . #charterschool #tca #soccer
#
# Annotator A: [('ORG', 'TCA'), ('LOC', 'Colorado')]
# Annotator B: [('ORG', 'Colorado 3A women'), ('ORG', 'soccer championship')]
# Annotator C: [('MISC', 'TCA'), ('MISC', 'Colorado 3A')]
# Baseline: [('ORG', 'TCA'), ('MISC', '3A')]
# Bertweet: [('ORG', 'TCA'), ('MISC', '3A')]
# Gold standard [('ORG', 'TCA'), ('MISC', "Colorado 3A women 's soccer championship")]
#
# ================================================================================
# TWEET 187
# TOKENS: TRUE BLOOD tonight ... still not sure I am gon na like the new XANADU style storyline they are getting into ... URL47
#
# Annotator A: [('MISC', 'TRUE BLOOD')]
# Annotator B: [('MISC', 'TRUE BLOOD'), ('MISC', 'XANADU')]
# Annotator C: []
# Baseline: [('ORG', 'XANADU')]
# Bertweet: [('MISC', 'TRUE BLOOD'), ('MISC', 'XANADU')]
# Gold standard [('MISC', 'TRUE BLOOD'), ('MISC', 'XANADU')]
#
# ================================================================================
# TWEET 190
# TOKENS: Twitter off#
#
# Annotator A: [('ORG', 'Twitter')]
# Annotator B: []
# Annotator C: [('ORG', 'Twitter')]
# Baseline: []
# Bertweet: [('ORG', 'Twitter')]
# Gold standard [('ORG', 'Twitter')]
#
# ================================================================================
# TWEET 195
# TOKENS: Welcome to our twitter page ! Here we will update you with our weekly specials and monthly giveaways !
#
# Annotator A: []
# Annotator B: []
# Annotator C: [('ORG', 'twitter')]
# Baseline: [('ORG', 'twitter')]
# Bertweet: []
# Gold standard [('ORG', 'twitter')]
#
# ================================================================================
# TWEET 197
# TOKENS: Whooaaaa bro these CELTICS are god dammmm babies !!! MAN UP
#
# Annotator A: [('ORG', 'CELTICS')]
# Annotator B: [('ORG', 'CELTICS')]
# Annotator C: []
# Baseline: [('ORG', 'CELTICS')]
# Bertweet: [('ORG', 'CELTICS')]
# Gold standard [('ORG', 'CELTICS')]
#
# ================================================================================
# TWEET 199
# TOKENS: Word I 'm bout to holla at her via twitter RT @USER1971 : #trushit - i m tryna fucc nicki minaj lol
#
# Annotator A: [('ORG', 'twitter'), ('PER', 'nicki minaj')]
# Annotator B: [('PER', 'nicki minaj')]
# Annotator C: []
# Baseline: [('ORG', 'twitter')]
# Bertweet: [('PER', 'nicki minaj')]
# Gold standard [('ORG', 'twitter'), ('PER', 'nicki minaj')]
#
# ================================================================================
# TWEET 203
# TOKENS: enjoys a good Snog at lunchtime .
#
# Annotator A: [('MISC', 'Snog')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 204
# TOKENS: going through my flickr .. just thought i d re-share my fave pic of @USER2542 from toronto warped . URL68 <3
#
# Annotator A: [('LOC', 'toronto')]
# Annotator B: [('LOC', 'toronto')]
# Annotator C: []
# Baseline: [('PER', 'toronto')]
# Bertweet: [('MISC', 'warped')]
# Gold standard [('ORG', 'flickr'), ('LOC', 'toronto')]
#
# ================================================================================
# TWEET 205
# TOKENS: it s sad that i m just now watching the Britney #Glee episode , smh
#
# Annotator A: [('PER', 'Britney')]
# Annotator B: [('MISC', 'Britney #Glee')]
# Annotator C: [('PER', 'Britney')]
# Baseline: [('PER', 'Britney')]
# Bertweet: [('PER', 'Britney')]
# Gold standard [('PER', 'Britney')]
#
# ================================================================================
# TWEET 208
# TOKENS: kid cudi is a faggot , that is all
#
# Annotator A: []
# Annotator B: [('PER', 'kid cudi')]
# Annotator C: []
# Baseline: [('PER', 'cudi')]
# Bertweet: [('PER', 'kid cudi')]
# Gold standard [('PER', 'kid cudi')]
#
# ================================================================================
# TWEET 212
# TOKENS: reading harry potter in bed ! waiting for the new south park to come on
#
# Annotator A: [('MISC', 'harry potter'), ('MISC', 'south park')]
# Annotator B: [('MISC', 'harry potter'), ('MISC', 'south park')]
# Annotator C: [('MISC', 'harry potter')]
# Baseline: [('MISC', 'park')]
# Bertweet: [('MISC', 'harry potter'), ('MISC', 'south park')]
# Gold standard [('MISC', 'harry potter'), ('MISC', 'south park')]
#
# ================================================================================
# TWEET 220
# TOKENS: RT @USER186 : Gavin McInnes –- Tattoo Advice from a Comedian URL787 URL1464
#
# Annotator A: [('PER', 'Gavin McInnes'), ('MISC', 'Tattoo Advice from a Comedian')]
# Annotator B: [('PER', 'Gavin McInnes')]
# Annotator C: [('PER', 'Gavin McInnes')]
# Baseline: [('PER', 'Gavin McInnes –-')]
# Bertweet: [('PER', 'Gavin McInnes')]
# Gold standard [('PER', 'Gavin McInnes')]
#
# ================================================================================
# TWEET 221
# TOKENS: Kiss Daniel – New Era ( Album Tracklist ) : The highly anticipated Kiss Daniel debut album , NEW ERA ... URL955 #Letsdanzit
#
# Annotator A: [('MISC', 'Kiss Daniel'), ('MISC', 'New Era')]
# Annotator B: [('ORG', 'Kiss Daniel'), ('MISC', 'New Era'), ('ORG', 'Kiss Daniel')]
# Annotator C: [('PER', 'Kiss Daniel'), ('MISC', 'New Era'), ('PER', 'Kiss Daniel')]
# Baseline: [('MISC', '– New Era'), ('ORG', 'Daniel')]
# Bertweet: [('PER', 'Kiss Daniel'), ('MISC', 'New Era'), ('PER', 'Kiss Daniel')]
# Gold standard [('PER', 'Kiss Daniel'), ('MISC', 'New Era'), ('PER', 'Kiss Daniel'), ('MISC', 'NEW ERA')]
#
# ================================================================================
# TWEET 228
# TOKENS: RT @USER226 : . @USER798 and her grave can be visited at St Peter 's Church in Bournemouth #MaryShelley URL1008
#
# Annotator A: [('MISC', "St Peter 's Church"), ('LOC', 'Bournemouth')]
# Annotator B: [('LOC', "St Peter 's Church"), ('LOC', 'Bournemouth')]
# Annotator C: [('LOC', 'St Peter'), ('LOC', 'Bournemouth')]
# Baseline: [('ORG', "'s Church"), ('LOC', 'Bournemouth')]
# Bertweet: [('LOC', "Peter 's Church"), ('LOC', 'Bournemouth')]
# Gold standard [('LOC', "St Peter 's Church"), ('LOC', 'Bournemouth')]
#
# ================================================================================
# TWEET 230
# TOKENS: #Deals #7994 3pcs 7.4 V 2000 mAh Battery + Charger For Syma X8W X8C X8G RC Quadcopter Banana P … URL248 URL658
#
# Annotator A: []
# Annotator B: [('MISC', 'Syma X8W X8C X8G RC Quadcopter Banana P')]
# Annotator C: []
# Baseline: [('MISC', 'Syma')]
# Bertweet: [('ORG', 'Syma')]
# Gold standard [('ORG', 'Syma')]
#
# ================================================================================
# TWEET 234
# TOKENS: RT @USER1345 : When the BBoyz bust out ampme at the school cafe 😂 URL1034
#
# Annotator A: [('MISC', 'BBoyz')]
# Annotator B: [('ORG', 'BBoyz')]
# Annotator C: [('MISC', 'BBoyz')]
# Baseline: [('ORG', 'BBoyz')]
# Bertweet: [('ORG', 'BBoyz')]
# Gold standard [('ORG', 'BBoyz'), ('MISC', 'ampme')]
#
# ================================================================================
# TWEET 235
# TOKENS: RT @USER2090 : This is Scalia speaking at a commencement in 2010 ... URL768
#
# Annotator A: [('PER', 'Scalia')]
# Annotator B: [('ORG', 'Scalia')]
# Annotator C: [('PER', 'Scalia')]
# Baseline: [('PER', 'Scalia')]
# Bertweet: [('PER', 'Scalia')]
# Gold standard [('PER', 'Scalia')]
#
# ================================================================================
# TWEET 240
# TOKENS: 14221 started on 08/05/2016 Reached its destination CPA and was 10 Mins Before URL945
#
# Annotator A: [('LOC', 'CPA')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: [('LOC', 'CPA')]
# Gold standard []
#
# ================================================================================
# TWEET 241
# TOKENS: visited Ky ❤️ they added so many babies it s cray
#
# Annotator A: [('ORG', 'Ky')]
# Annotator B: [('PER', 'Ky')]
# Annotator C: [('LOC', 'Ky')]
# Baseline: []
# Bertweet: [('LOC', 'Ky')]
# Gold standard [('LOC', 'Ky')]
#
# ================================================================================
# TWEET 243
# TOKENS: RT @USER281 : Discover Various Facts about Reptiles From KidRhymes - URL535
#
# Annotator A: [('MISC', 'KidRhymes')]
# Annotator B: [('ORG', 'KidRhymes')]
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard [('MISC', 'KidRhymes')]
#
# ================================================================================
# TWEET 247
# TOKENS: RT @USER151 : Mean Girls URL582
#
# Annotator A: []
# Annotator B: [('MISC', 'Mean Girls')]
# Annotator C: []
# Baseline: [('MISC', 'Mean Girls')]
# Bertweet: [('MISC', 'Mean Girls')]
# Gold standard [('MISC', 'Mean Girls')]
#
# ================================================================================
# TWEET 250
# TOKENS: RT @USER1266 : #BOHO JEWELRY #Bohemian #Jewelry Stretch #Bracelet #etsy #handmade by JabberDuck URL770 URL225 …
#
# Annotator A: []
# Annotator B: [('PER', 'JabberDuck')]
# Annotator C: []
# Baseline: [('ORG', 'JabberDuck')]
# Bertweet: [('PER', 'JabberDuck')]
# Gold standard [('ORG', 'JabberDuck')]
#
# ================================================================================
# TWEET 252
# TOKENS: RT @USER408 : Scientist : we 've finally taught a dog Morse Code Dog : [ taps paw ] Me : what did it say ? Scientist : " woof "
#
# Annotator A: [('MISC', 'Morse Code')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 255
# TOKENS: it 's game day ... go stangs !
#
# Annotator A: []
# Annotator B: [('ORG', 'stangs')]
# Annotator C: []
# Baseline: []
# Bertweet: [('ORG', 'stangs')]
# Gold standard [('ORG', 'stangs')]
#
# ================================================================================
# TWEET 256
# TOKENS: RT @USER1926 : Who was removed aftr #GHQ . #MehranBase , #KamraBae , #ParadeLane attacks ? Y #BKU vice - chancellor ? #Marwat Saeb is a prof nt Ge …
#
# Annotator A: []
# Annotator B: [('PER', '#MehranBase'), ('PER', '#KamraBae')]
# Annotator C: []
# Baseline: [('PER', 'Saeb')]
# Bertweet: [('PER', 'Saeb')]
# Gold standard []
#
# ================================================================================
# TWEET 257
# TOKENS: ♬ Mass Effect ( Original Mix ) - Audiocells
#
# Annotator A: [('MISC', 'Mass Effect'), ('MISC', 'Audiocells')]
# Annotator B: [('MISC', 'Mass Effect'), ('ORG', 'Audiocells')]
# Annotator C: [('MISC', 'Mass Effect')]
# Baseline: [('MISC', 'Mass Effect'), ('MISC', 'Audiocells')]
# Bertweet: [('MISC', 'Mass Effect'), ('ORG', 'Audiocells')]
# Gold standard [('MISC', 'Mass Effect'), ('ORG', 'Audiocells')]
#
# ================================================================================
# TWEET 263
# TOKENS: @USER1935 as a Muslim do you also support pedophillia and violent extremism ? Scrolled thru ur tweets , did n't see you speak against that
#
# Annotator A: [('MISC', 'Muslim')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: [('MISC', 'pedophillia')]
# Gold standard [('MISC', 'Muslim')]
#
# ================================================================================
# TWEET 267
# TOKENS: RT @USER2568 : the red stan . constantly talks about the album and her long straight hair . bitter red did n't win a grammy . probably has a nic …
#
# Annotator A: []
# Annotator B: [('MISC', 'the red stan'), ('MISC', 'red')]
# Annotator C: []
# Baseline: []
# Bertweet: [('MISC', 'red'), ('MISC', 'grammy')]
# Gold standard [('MISC', 'grammy')]
#
# ================================================================================
# TWEET 268
# TOKENS: RT @USER1814 : Discover how scrubbing dots make the difference w/ the Scrubbing Dish Cloth ! #ScrubCloth #sweepstakes URL961 …
#
# Annotator A: []
# Annotator B: [('MISC', 'Scrubbing Dish Cloth')]
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 269
# TOKENS: RT @USER1272 : A lot of R3 orphans and widows are afflicted by Stockholm Syndrome and are craving for attention of PTs in Twitter
#
# Annotator A: [('MISC', 'Stockholm Syndrome'), ('ORG', 'Twitter')]
# Annotator B: []
# Annotator C: [('MISC', 'Stockholm Syndrome'), ('ORG', 'Twitter')]
# Baseline: [('MISC', 'R3'), ('MISC', 'Stockholm Syndrome'), ('ORG', 'Twitter')]
# Bertweet: [('ORG', 'Twitter')]
# Gold standard [('MISC', 'Stockholm Syndrome'), ('ORG', 'Twitter')]
#
# ================================================================================
# TWEET 271
# TOKENS: RT @USER1354 : If keyboards came with braille on them , we all could have subconsciously learned braille by now .
#
# Annotator A: [('MISC', 'braille'), ('MISC', 'braille')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 273
# TOKENS: RT @USER1247 : T 2315 - Amazing moment : Raj Kapoor , Shammi Kapoor , Shashi Kapoor with their Mother .. URL755
#
# Annotator A: [('PER', 'Raj Kapoor'), ('PER', 'Shammi Kapoor'), ('PER', 'Shashi Kapoor')]
# Annotator B: [('PER', 'Raj Kapoor'), ('PER', 'Shammi Kapoor'), ('PER', 'Shashi Kapoor')]
# Annotator C: [('PER', 'Raj Kapoor'), ('PER', 'Shammi Kapoor'), ('PER', ','), ('PER', 'Shashi Kapoor')]
# Baseline: [('PER', 'Raj Kapoor'), ('PER', 'Shammi Kapoor'), ('PER', 'Shashi Kapoor')]
# Bertweet: [('PER', 'Raj Kapoor'), ('PER', 'Shammi Kapoor'), ('PER', 'Shashi Kapoor')]
# Gold standard [('PER', 'Raj Kapoor'), ('PER', 'Shammi Kapoor'), ('PER', 'Shashi Kapoor')]
#
# ================================================================================
# TWEET 283
# TOKENS: @USER2299 Nikki no , you ’re better than that
#
# Annotator A: []
# Annotator B: [('PER', 'Nikki')]
# Annotator C: [('PER', 'Nikki')]
# Baseline: [('PER', 'Nikki')]
# Bertweet: [('PER', 'Nikki')]
# Gold standard [('PER', 'Nikki')]
#
# ================================================================================
# TWEET 284
# TOKENS: RT @USER561 : Trump " does n’t care who gets hurt as long as he makes a profit off it . That can not be the person who leads the United S …
#
# Annotator A: [('PER', 'Trump'), ('LOC', 'United S')]
# Annotator B: [('PER', 'Trump'), ('ORG', 'S …')]
# Annotator C: [('PER', 'Trump')]
# Baseline: [('PER', 'Trump'), ('MISC', 'S …')]
# Bertweet: [('PER', 'Trump'), ('LOC', 'S')]
# Gold standard [('PER', 'Trump'), ('LOC', 'United S')]
#
# ================================================================================
# TWEET 287
# TOKENS: @USER2335 You ’re on the list ! We ’re on our way with Red Bull to help you through your workday .
#
# Annotator A: [('MISC', 'Red Bull')]
# Annotator B: [('ORG', 'Red Bull')]
# Annotator C: []
# Baseline: [('ORG', 'Red Bull')]
# Bertweet: [('ORG', 'Red Bull')]
# Gold standard [('ORG', 'Red Bull')]
#
# ================================================================================
# TWEET 291
# TOKENS: RT @USER201 : 14th Feb 2015 : World Cup first match 14th Feb 2016 : Ind vs SL T20 Cricket lovers have a reason to Celebrate Valentine …
#
# Annotator A: [('MISC', 'World Cup'), ('MISC', 'Valentine')]
# Annotator B: [('MISC', 'World Cup'), ('ORG', 'Ind'), ('ORG', 'SL T20')]
# Annotator C: [('ORG', 'World Cup'), ('MISC', 'Valentine')]
# Baseline: [('MISC', 'World Cup'), ('ORG', 'Ind'), ('MISC', 'T20'), ('PER', 'Valentine')]
# Bertweet: [('MISC', 'World Cup'), ('ORG', 'Ind'), ('ORG', 'SL')]
# Gold standard [('MISC', 'World Cup'), ('ORG', 'Ind'), ('ORG', 'SL')]
#
# ================================================================================
# TWEET 293
# TOKENS: RT @USER2360 : 2ne1 will forever be my favorite girl group 💕 #7YearsWith2NE1 URL1202
#
# Annotator A: []
# Annotator B: [('MISC', '2ne1')]
# Annotator C: []
# Baseline: []
# Bertweet: [('ORG', '2ne1')]
# Gold standard [('ORG', '2ne1')]
#
# ================================================================================
# TWEET 299
# TOKENS: @USER425 < Kira is committing a crime himself . Everyone commits crimes , even the ones who keep crimes from being done . " L pressed >
#
# Annotator A: []
# Annotator B: [('PER', 'Kira')]
# Annotator C: [('PER', 'Kira')]
# Baseline: [('PER', 'Kira')]
# Bertweet: [('PER', 'Kira')]
# Gold standard []
#
# ================================================================================
# TWEET 300
# TOKENS: Lake Wind Advisory in effect from 9 AM for Angelina , Cherokee , Nacogdoches , Sabine and San Augustine Counties #txwx URL1304
#
# Annotator A: [('MISC', 'Lake Wind Advisory'), ('LOC', 'Angelina'), ('LOC', 'Cherokee'), ('LOC', 'Nacogdoches'), ('LOC', 'Sabine'), ('LOC', 'San Augustine')]
# Annotator B: [('ORG', 'Lake Wind Advisory'), ('LOC', 'Angelina'), ('LOC', 'Cherokee'), ('LOC', 'Nacogdoches'), ('LOC', 'Sabine'), ('LOC', 'San Augustine')]
# Annotator C: [('LOC', 'Angelina'), ('LOC', 'Cherokee'), ('LOC', 'Nacogdoches'), ('LOC', 'Sabine'), ('LOC', 'San Augustine')]
# Baseline: [('MISC', 'Lake'), ('LOC', 'Angelina'), ('LOC', 'Cherokee'), ('LOC', 'Nacogdoches'), ('LOC', 'Sabine'), ('LOC', 'San Augustine Counties')]
# Bertweet: [('LOC', 'Angelina'), ('LOC', 'Cherokee'), ('LOC', 'Nacogdoches'), ('LOC', 'Sabine'), ('LOC', 'San Augustine')]
# Gold standard [('LOC', 'Angelina'), ('LOC', 'Cherokee'), ('LOC', 'Nacogdoches'), ('LOC', 'Sabine'), ('LOC', 'San Augustine Counties')]
#
# ================================================================================
# TWEET 306
# TOKENS: ' Repair Matters ' group hopes to empower people with fix it skills URL550
#
# Annotator A: [('MISC', 'Repair Matters')]
# Annotator B: [('ORG', 'Repair Matters')]
# Annotator C: []
# Baseline: []
# Bertweet: [('MISC', 'Repair')]
# Gold standard [('ORG', 'Repair Matters')]
#
# ================================================================================
# TWEET 309
# TOKENS: RT @USER896 : Chris Brown started the trend of freestyle dancing to " young thug / future / rich homie quan " songs during his concerts . I see …
#
# Annotator A: [('PER', 'Chris Brown')]
# Annotator B: [('PER', 'Brown'), ('PER', 'young thug'), ('PER', 'future'), ('PER', 'rich homie quan')]
# Annotator C: [('PER', 'Chris Brown')]
# Baseline: [('PER', 'Chris Brown')]
# Bertweet: [('PER', 'Chris Brown'), ('PER', 'young thug'), ('PER', 'future'), ('PER', 'rich homie quan')]
# Gold standard [('PER', 'Chris Brown'), ('MISC', 'young thug'), ('MISC', 'future'), ('MISC', 'rich homie quan')]
#
# ================================================================================
# TWEET 312
# TOKENS: RT @USER10 : Indianapolis wicked wicked wicked vibes .. purple reign fanatics ☔️ love forever
#
# Annotator A: [('ORG', 'Indianapolis')]
# Annotator B: [('LOC', 'Indianapolis')]
# Annotator C: [('LOC', 'Indianapolis')]
# Baseline: [('LOC', 'Indianapolis')]
# Bertweet: [('LOC', 'Indianapolis')]
# Gold standard [('LOC', 'Indianapolis'), ('MISC', 'purple reign')]
#
# ================================================================================
# TWEET 321
# TOKENS: RT @USER1753 : No lie GSU was lit on this night #GSU #StateNotSouthern URL368
#
# Annotator A: [('MISC', 'GSU')]
# Annotator B: [('ORG', 'GSU')]
# Annotator C: [('ORG', 'GSU')]
# Baseline: [('MISC', 'GSU')]
# Bertweet: []
# Gold standard [('ORG', 'GSU')]
#
# ================================================================================
# TWEET 322
# TOKENS: RT @USER295 : Senegal 's Lake Retba owes its pink color to the presence of carotenoids produced by an algae . #Senegal #funfacts URL221 …
#
# Annotator A: [('LOC', 'Senegal'), ('LOC', 'Lake Retba')]
# Annotator B: [('LOC', 'Senegal'), ('LOC', 'Lake Retba')]
# Annotator C: [('LOC', 'Senegal'), ('MISC', 'Lake Retba')]
# Baseline: [('LOC', 'Senegal'), ('LOC', 'Retba')]
# Bertweet: [('LOC', 'Senegal'), ('LOC', 'Lake Retba')]
# Gold standard [('LOC', 'Senegal'), ('LOC', 'Lake Retba')]
#
# ================================================================================
# TWEET 324
# TOKENS: Revealed Radio 070 - The Chainsmokers and Hardwell URL1042 🔥🙌👏
#
# Annotator A: [('MISC', 'Revealed Radio'), ('MISC', 'The Chainsmokers and Hardwell')]
# Annotator B: [('ORG', 'The Chainsmokers'), ('ORG', 'Hardwell')]
# Annotator C: [('MISC', 'The Chainsmokers'), ('MISC', 'Hardwell')]
# Baseline: [('MISC', 'The'), ('ORG', 'Chainsmokers'), ('MISC', 'Hardwell')]
# Bertweet: [('PER', 'Chainsmokers'), ('PER', 'Hardwell')]
# Gold standard [('MISC', 'Revealed Radio')]
#
# ================================================================================
# TWEET 329
# TOKENS: Great chance to nominate the best & brightest from our AMC community ! URL1351 #assnchat #assnprofs
#
# Annotator A: [('ORG', 'AMC')]
# Annotator B: []
# Annotator C: []
# Baseline: [('MISC', 'AMC')]
# Bertweet: [('ORG', 'AMC')]
# Gold standard [('ORG', 'AMC')]
#
# ================================================================================
# TWEET 330
# TOKENS: Your Local Doppler Radar URL891 #roundrock
#
# Annotator A: [('MISC', 'Doppler')]
# Annotator B: []
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard [('MISC', 'Doppler')]
#
# ================================================================================
# TWEET 333
# TOKENS: 📷 Purchase my special edition of Alternative Revolution Magazine at URL748 URL888
#
# Annotator A: [('MISC', 'Revolution Magazine')]
# Annotator B: [('MISC', 'Alternative Revolution Magazine')]
# Annotator C: [('MISC', 'Alternative Revolution Magazine')]
# Baseline: [('MISC', 'Alternative Revolution Magazine')]
# Bertweet: [('ORG', 'Alternative Revolution Magazine')]
# Gold standard [('ORG', 'Alternative Revolution Magazine')]
#
# ================================================================================
# TWEET 342
# TOKENS: Yamaha ’s Rossi gets contract extension through 2018 : Valentino Rossi has extended his contract with Yamaha for ... URL849
#
# Annotator A: [('ORG', 'Yamaha'), ('PER', 'Rossi'), ('PER', 'Valentino Rossi'), ('ORG', 'Yamaha')]
# Annotator B: [('PER', 'Yamaha ’s Rossi'), ('PER', 'Valentino Rossi'), ('ORG', 'Yamaha')]
# Annotator C: [('MISC', 'Yamaha'), ('PER', 'Rossi'), ('PER', 'Valentino Rossi'), ('MISC', 'Yamaha')]
# Baseline: [('ORG', 'Yamaha'), ('PER', 'Rossi'), ('PER', 'Valentino Rossi'), ('ORG', 'Yamaha')]
# Bertweet: [('ORG', 'Yamaha'), ('PER', 'Rossi'), ('PER', 'Valentino Rossi'), ('ORG', 'Yamaha')]
# Gold standard [('ORG', 'Yamaha'), ('PER', 'Rossi'), ('PER', 'Valentino Rossi'), ('ORG', 'Yamaha')]
#
# ================================================================================
# TWEET 344
# TOKENS: RT @USER702 : ' Jesus please mention my name when you talk to your Father today ... ' 🙏🏽
#
# Annotator A: [('MISC', 'Jesus')]
# Annotator B: [('PER', 'Jesus')]
# Annotator C: [('PER', 'Jesus')]
# Baseline: [('PER', 'Jesus')]
# Bertweet: [('PER', 'Jesus')]
# Gold standard [('PER', 'Jesus')]
#
# ================================================================================
# TWEET 346
# TOKENS: RT @USER451 : Naruto : Hey let 's go get some ramen !! Sasuke : shut up and get off my lawn , loser Itachi : now now Sasuke be nice URL221 …
#
# Annotator A: [('PER', 'Naruto'), ('PER', 'Sasuke'), ('PER', 'Itachi'), ('PER', 'Sasuke')]
# Annotator B: [('PER', 'Naruto'), ('PER', 'Sasuke'), ('PER', 'Itachi'), ('PER', 'Sasuke')]
# Annotator C: [('PER', 'Naruto'), ('PER', 'Sasuke'), ('PER', 'loser'), ('PER', 'Itachi'), ('PER', 'Sasuke')]
# Baseline: [('PER', 'Naruto'), ('PER', 'Sasuke'), ('PER', 'Itachi'), ('PER', 'Sasuke')]
# Bertweet: [('PER', 'Naruto'), ('PER', 'Sasuke'), ('PER', 'Itachi'), ('PER', 'Sasuke')]
# Gold standard [('PER', 'Naruto'), ('PER', 'Sasuke'), ('PER', 'Itachi'), ('PER', 'Sasuke')]
#
# ================================================================================
# TWEET 347
# TOKENS: BETFAIR - Bet £ 10 Get £ 30 + Double Winnings on Everton v Man Utd if both teams score URL242 #FACup URL1139
#
# Annotator A: [('ORG', 'Everton'), ('ORG', 'Man Utd')]
# Annotator B: [('ORG', 'Everton'), ('ORG', 'Man Utd')]
# Annotator C: [('MISC', 'Everton'), ('MISC', 'Man Utd')]
# Baseline: [('ORG', 'BETFAIR'), ('ORG', 'Everton'), ('ORG', 'Man')]
# Bertweet: [('ORG', 'Everton'), ('ORG', 'Man Utd')]
# Gold standard [('ORG', 'BETFAIR'), ('ORG', 'Everton'), ('ORG', 'Man Utd')]
#
# ================================================================================
# TWEET 353
# TOKENS: RT @USER2501 : ( credits to blackangel94a on tumblr ) URL1577
#
# Annotator A: [('MISC', 'tumblr')]
# Annotator B: [('PER', 'blackangel94a'), ('ORG', 'tumblr')]
# Annotator C: []
# Baseline: [('PER', 'blackangel94a')]
# Bertweet: [('PER', 'blackangel94a'), ('ORG', 'tumblr')]
# Gold standard [('PER', 'blackangel94a'), ('ORG', 'tumblr')]
#
# ================================================================================
# TWEET 354
# TOKENS: RT @USER2052 : qn : which artist do you want to collab with the most ? hansol : Any URL1628
#
# Annotator A: []
# Annotator B: [('PER', 'hansol')]
# Annotator C: []
# Baseline: [('PER', 'hansol')]
# Bertweet: [('PER', 'hansol')]
# Gold standard [('PER', 'hansol')]
#
# ================================================================================
# TWEET 357
# TOKENS: RT @USER1425 : The UNCOMFORTABLE CONVERSATIONS series starts today !!! Make sure your there !!! @ LTB 5 , 6 - 8 PM . URL1048
#
# Annotator A: []
# Annotator B: [('MISC', 'UNCOMFORTABLE CONVERSATIONS')]
# Annotator C: []
# Baseline: [('MISC', 'UNCOMFORTABLE'), ('MISC', 'CONVERSATIONS')]
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 360
# TOKENS: RT @USER2453 : @USER1838 good evening ! ( japan time ) ! Thank you very much ! Friendly Corina Dumitrescu 's ! Nature is Beautiful ! spen …
#
# Annotator A: [('LOC', 'japan'), ('PER', 'Corina Dumitrescu')]
# Annotator B: [('LOC', 'japan'), ('PER', 'Corina Dumitrescu')]
# Annotator C: [('LOC', '('), ('LOC', 'japan'), ('PER', 'Corina Dumitrescu')]
# Baseline: [('LOC', 'japan'), ('PER', 'Corina Dumitrescu')]
# Bertweet: [('LOC', 'japan'), ('PER', 'Corina Dumitrescu')]
# Gold standard [('PER', 'Corina Dumitrescu')]
#
# ================================================================================
# TWEET 361
# TOKENS: Joebarly Feat. HitMaker Q – Widd It URL1474 Major #HipHop
#
# Annotator A: [('PER', 'Joebarly'), ('MISC', 'HitMaker'), ('MISC', 'Widd It')]
# Annotator B: [('PER', 'Joebarly'), ('PER', 'HitMaker Q')]
# Annotator C: [('MISC', 'Joebarly'), ('MISC', 'HitMaker Q')]
# Baseline: [('PER', 'Joebarly'), ('MISC', 'HitMaker')]
# Bertweet: [('PER', 'Joebarly'), ('PER', 'HitMaker'), ('PER', 'Q'), ('MISC', 'Widd It')]
# Gold standard [('PER', 'Joebarly'), ('PER', 'HitMaker Q'), ('MISC', 'Widd It')]
#
# ...
# TWEET 412
# TOKENS: BJ the Chicago Kid Talks Kendrick Lamar & Repping the ' New R&B ' on Motown Debut Album : Moving to Los Angeles a ... URL772
#
# Annotator A: [('MISC', 'BJ the Chicago Kid'), ('PER', 'Kendrick Lamar'), ('MISC', 'Moving to Los Angeles')]
# Annotator B: [('PER', 'BJ the Chicago Kid'), ('PER', 'Kendrick Lamar'), ('ORG', 'Motown'), ('LOC', 'Los Angeles')]
# Annotator C: [('MISC', 'Chicago Kid'), ('PER', 'Kendrick Lamar'), ('MISC', 'Motown Debut'), ('LOC', 'Los Angeles')]
# Baseline: [('PER', 'BJ'), ('MISC', 'Kid'), ('PER', 'Kendrick Lamar'), ('ORG', 'Motown'), ('LOC', 'Los'), ('LOC', 'Angeles')]
# Bertweet: [('PER', 'BJ the Chicago Kid'), ('PER', 'Kendrick Lamar'), ('ORG', 'Motown'), ('LOC', 'Los Angeles')]
# Gold standard [('PER', 'BJ the Chicago Kid'), ('PER', 'Kendrick Lamar'), ('LOC', 'Motown'), ('LOC', 'Los Angeles')]
#
# ================================================================================
# TWEET 422
# TOKENS: RT @USER959 : #NewportNews #Virginia boy leaves Gatorade , water for #LetterCarrier URL938 via @USER6 URL224 …
#
# Annotator A: [('ORG', 'Gatorade')]
# Annotator B: [('ORG', 'Gatorade')]
# Annotator C: []
# Baseline: [('MISC', 'Gatorade')]
# Bertweet: []
# Gold standard [('ORG', 'Gatorade')]
#
# ================================================================================
# TWEET 423
# TOKENS: The old niggas on Dr Dre album Lowkey be taking hella shots at the new niggas lol
#
# Annotator A: [('PER', 'Dr Dre'), ('MISC', 'Lowkey')]
# Annotator B: [('PER', 'Dr Dre')]
# Annotator C: [('PER', 'Dr Dre')]
# Baseline: [('PER', 'Dr Dre'), ('PER', 'Lowkey')]
# Bertweet: [('PER', 'Dr Dre')]
# Gold standard [('PER', 'Dr Dre')]
#
# ================================================================================
# TWEET 425
# TOKENS: Egyptian writer Ahmed Naji ’s crime is n't what he wrote – it is that he is alive URL607
#
# Annotator A: [('MISC', 'Egyptian'), ('PER', 'Ahmed Naji')]
# Annotator B: [('PER', 'Ahmed Naji')]
# Annotator C: [('PER', 'Ahmed Naji')]
# Baseline: [('PER', 'Egyptian'), ('PER', 'Ahmed Naji')]
# Bertweet: [('MISC', 'Egyptian'), ('PER', 'Ahmed Naji')]
# Gold standard [('MISC', 'Egyptian'), ('PER', 'Ahmed Naji')]
#
# ================================================================================
# TWEET 426
# TOKENS: RT @USER919 : Great setting for @USER1033 Falmouth GP of the Sea 2017 URL461
#
# Annotator A: []
# Annotator B: [('LOC', 'Falmouth GP')]
# Annotator C: []
# Baseline: [('MISC', 'GP of'), ('MISC', 'Sea')]
# Bertweet: [('MISC', 'GP'), ('MISC', 'Sea')]
# Gold standard [('MISC', 'Falmouth GP of the Sea 2017')]
#
# ================================================================================
# TWEET 428
# TOKENS: RT @USER1256 : " We need some payday lending reforms . " - Alabama Banking Department Superintendent John Harrison URL1181 …
#
# Annotator A: [('LOC', 'Alabama'), ('PER', 'John Harrison')]
# Annotator B: [('ORG', 'Alabama Banking Department'), ('PER', 'John Harrison')]
# Annotator C: [('ORG', 'Alabama Banking Department'), ('PER', 'John Harrison')]
# Baseline: [('LOC', 'Alabama'), ('ORG', 'Department'), ('PER', 'John Harrison')]
# Bertweet: [('ORG', 'Banking Department'), ('MISC', 'Superintendent'), ('PER', 'John Harrison')]
# Gold standard [('ORG', 'Alabama Banking Department'), ('PER', 'John Harrison')]
#
# ================================================================================
# TWEET 429
# TOKENS: RT @USER2347 : For the highest ticket prices in world football , we 're ' entitled ' to expect more than zero PL / CL titles in 12 yrs . URL219 …
#
# Annotator A: [('MISC', 'PL'), ('MISC', 'CL')]
# Annotator B: []
# Annotator C: []
# Baseline: [('MISC', 'world')]
# Bertweet: [('MISC', 'PL'), ('MISC', 'CL')]
# Gold standard [('ORG', 'PL'), ('ORG', 'CL')]
#
# ================================================================================
# TWEET 430
# TOKENS: Now playing on OSN Radio ( @USER2325 ) Another Day ( Perfecto Mix ) by Skip Raiders #OSN #NowPlaying ( URL1112 )
#
# Annotator A: [('ORG', 'OSN Radio'), ('MISC', 'Another Day'), ('PER', 'Skip Raiders')]
# Annotator B: [('ORG', 'OSN Radio'), ('MISC', 'Another Day'), ('ORG', 'Skip Raiders')]
# Annotator C: [('ORG', 'OSN Radio'), ('MISC', 'Another Day'), ('PER', 'Skip Raiders')]
# Baseline: [('ORG', 'OSN'), ('MISC', 'Another Day'), ('ORG', 'Raiders')]
# Bertweet: [('ORG', 'OSN'), ('MISC', 'Another Day'), ('MISC', 'Perfecto'), ('PER', 'Skip Raiders')]
# Gold standard [('ORG', 'OSN Radio'), ('MISC', 'Another Day ( Perfecto Mix )'), ('ORG', 'Skip Raiders')]
#
# ================================================================================
# TWEET 438
# TOKENS: Genocide in #Yemen yet world silence . Very strange : for US & #Europe , Yemen does n't exist ! Can You explain ? #ForgottenWarInYemen
#
# Annotator A: [('LOC', 'US'), ('LOC', 'Yemen')]
# Annotator B: [('LOC', 'US'), ('LOC', 'Yemen')]
# Annotator C: [('LOC', 'Yemen')]
# Baseline: [('LOC', 'US'), ('LOC', 'Yemen')]
# Bertweet: [('LOC', 'US'), ('LOC', 'Yemen')]
# Gold standard [('LOC', 'US'), ('LOC', 'Yemen')]
#
# ================================================================================
# TWEET 443
# TOKENS: RT @USER849 : TWITTER TEAM DOING PABEBE WAVE with @USER2199 STANDEE #VoteMaineFPP #KCA URL651
#
# Annotator A: [('ORG', 'TWITTER'), ('MISC', 'PABEBE WAVE')]
# Annotator B: [('MISC', 'PABEBE WAVE')]
# Annotator C: [('ORG', 'TWITTER')]
# Baseline: []
# Bertweet: [('ORG', 'TWITTER'), ('MISC', 'PABEBE')]
# Gold standard [('ORG', 'TWITTER'), ('MISC', 'PABEBE WAVE')]
#
# ================================================================================
# TWEET 449
# TOKENS: RT @USER573 : Angela Eagle : I went to Uni thanks to a Labour Govt Govt when Angela Eagle went to Uni : Thatcher ( Graduated in 1983 , St …
#
# Annotator A: [('PER', 'Angela Eagle'), ('PER', 'Angela Eagle'), ('PER', 'Thatcher')]
# Annotator B: [('PER', 'Angela Eagle'), ('ORG', 'Labour Govt'), ('PER', 'Angela Eagle'), ('PER', 'Thatcher')]
# Annotator C: [('PER', 'Angela Eagle'), ('PER', 'Angela Eagle')]
# Baseline: [('PER', 'Angela Eagle'), ('ORG', 'Uni'), ('PER', 'Angela Eagle'), ('ORG', 'Uni'), ('PER', 'Thatcher'), ('LOC', 'St'), ('LOC', '…')]
# Bertweet: [('PER', 'Angela Eagle'), ('ORG', 'Labour'), ('PER', 'Angela Eagle'), ('PER', 'Thatcher')]
# Gold standard [('PER', 'Angela Eagle'), ('MISC', 'Uni'), ('ORG', 'Labour Govt'), ('PER', 'Angela Eagle'), ('MISC', 'Uni'), ('PER', 'Thatcher')]
#
# ================================================================================
# TWEET 453
# TOKENS: RT @USER474 : Character progression through all 10 seasons of Friends ... URL378
#
# Annotator A: [('MISC', 'Friends')]
# Annotator B: [('MISC', 'Friends')]
# Annotator C: []
# Baseline: [('MISC', 'Friends')]
# Bertweet: [('MISC', 'Friends')]
# Gold standard [('MISC', 'Friends')]
#
# ================================================================================
# TWEET 455
# TOKENS: RT @USER213 : Funding legal services focus of AG ’s pre-election debate URL513 via @USER2151
#
# Annotator A: []
# Annotator B: [('ORG', 'AG')]
# Annotator C: [('ORG', 'AG')]
# Baseline: [('ORG', 'AG')]
# Bertweet: [('PER', 'AG')]
# Gold standard []
#
# ================================================================================
# TWEET 460
# TOKENS: #VOZEMPIRE : Ready to Divorce ? David Beckham Resigned From Victoria ’s Fashion Company URL360
#
# Annotator A: [('PER', 'David Beckham'), ('PER', 'Victoria')]
# Annotator B: [('PER', 'David Beckham'), ('ORG', 'Victoria')]
# Annotator C: [('PER', 'David Beckham'), ('PER', 'Victoria')]
# Baseline: [('PER', 'David Beckham'), ('ORG', 'Victoria ’s Fashion Company')]
# Bertweet: [('PER', 'David Beckham'), ('PER', 'Victoria')]
# Gold standard [('PER', 'David Beckham'), ('PER', 'Victoria')]
#
# ================================================================================
# TWEET 462
# TOKENS: RT @USER286 : Early Bird tickets are now Sold Out !! Get your #CountryFlo passes while supplies last : URL453 URL220 …
#
# Annotator A: []
# Annotator B: [('MISC', '#CountryFlo')]
# Annotator C: [('MISC', 'Early Bird')]
# Baseline: [('MISC', 'Early Bird')]
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 467
# TOKENS: RT @USER515 : " It does n't matter how much you have . It all means nothing if you are not happy with yourself . " Donald Duck #quotes htt …
#
# Annotator A: [('MISC', 'Donald Duck')]
# Annotator B: [('PER', 'Donald Duck')]
# Annotator C: [('PER', 'Donald Duck')]
# Baseline: [('PER', 'Donald Duck')]
# Bertweet: [('PER', 'Donald Duck')]
# Gold standard [('PER', 'Donald Duck')]
#
# ================================================================================
# TWEET 468
# TOKENS: pursuing the opposite : complain against EU red tape --> Seek EXCEPTIONAL treatment --> Get ever more red tape @USER2384 URL417
#
# Annotator A: [('ORG', 'EU')]
# Annotator B: []
# Annotator C: [('ORG', 'EU')]
# Baseline: [('MISC', 'EU')]
# Bertweet: [('ORG', 'EU')]
# Gold standard [('ORG', 'EU')]
#
# ================================================================================
# TWEET 471
# TOKENS: Jewellery belonging to the Duchess of Windsor was auctioned today in 1987 in Geneva , raising £ 31 M for medical research .
#
# Annotator A: [('PER', 'Duchess of Windsor'), ('LOC', 'Geneva')]
# Annotator B: [('PER', 'Duchess of Windsor'), ('LOC', 'Geneva')]
# Annotator C: [('PER', 'Duchess of Windsor'), ('LOC', 'in'), ('LOC', 'Geneva')]
# Baseline: [('PER', 'of Windsor'), ('LOC', 'Geneva')]
# Bertweet: [('PER', 'Duchess of Windsor'), ('LOC', 'Geneva')]
# Gold standard [('PER', 'Duchess of Windsor'), ('LOC', 'Geneva')]
#
# ================================================================================
# TWEET 472
# TOKENS: Middle - Eastern relationships will go through the roof URL994
#
# Annotator A: [('LOC', 'Middle'), ('LOC', 'Eastern')]
# Annotator B: []
# Annotator C: [('LOC', 'Middle - Eastern')]
# Baseline: []
# Bertweet: [('MISC', 'Middle'), ('MISC', 'Eastern')]
# Gold standard [('MISC', 'Middle - Eastern')]
#
# ================================================================================
# TWEET 474
# TOKENS: #porn More free @ URL1029 No Tricks ! #gayporn #gaygif #chaturbate #gayvideo URL1477
#
# Annotator A: []
# Annotator B: [('ORG', '#chaturbate')]
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard []
#
# ================================================================================
# TWEET 476
# TOKENS: Disastorus first innigs SL performed very well 2nd innings lead by 33 runs 3 wickets left for SL #ENGvSL
#
# Annotator A: [('ORG', 'SL'), ('ORG', 'SL')]
# Annotator B: [('ORG', 'SL'), ('ORG', 'SL')]
# Annotator C: []
# Baseline: [('ORG', 'SL')]
# Bertweet: [('ORG', 'SL'), ('ORG', 'SL')]
# Gold standard [('ORG', 'SL'), ('ORG', 'SL')]
#
# ================================================================================
# TWEET 478
# TOKENS: #NowPlaying Meathook Seed URL910
#
# Annotator A: [('MISC', 'Meathook Seed')]
# Annotator B: [('MISC', 'Meathook')]
# Annotator C: [('MISC', 'Meathook Seed')]
# Baseline: [('MISC', 'Meathook')]
# Bertweet: [('ORG', 'Meathook')]
# Gold standard [('MISC', 'Meathook Seed')]
#
# ================================================================================
# TWEET 479
# TOKENS: RT @USER132 : JDR did n't really address Mario Edwards being cleared ... he 's excited that Mario is part of team on the field .
#
# Annotator A: [('ORG', 'JDR'), ('PER', 'Mario Edwards'), ('PER', 'Mario')]
# Annotator B: [('PER', 'Mario Edwards'), ('PER', 'Mario')]
# Annotator C: [('PER', 'JDR'), ('PER', 'Mario Edwards'), ('PER', 'Mario')]
# Baseline: [('PER', 'JDR'), ('PER', 'Mario Edwards'), ('PER', 'Mario')]
# Bertweet: [('PER', 'JDR'), ('PER', 'Mario Edwards'), ('PER', 'Mario')]
# Gold standard [('PER', 'JDR'), ('PER', 'Mario Edwards'), ('PER', 'Mario')]
#
# ================================================================================
# TWEET 481
# TOKENS: " Sorry I ca n't work on July 9th because everyone is leaving Hamilton & I 'm emotionally invested in their existence . "
#
# Annotator A: [('MISC', 'Hamilton')]
# Annotator B: [('MISC', 'Hamilton')]
# Annotator C: [('PER', 'leaving'), ('PER', 'Hamilton')]
# Baseline: [('LOC', 'Hamilton')]
# Bertweet: [('LOC', 'Hamilton')]
# Gold standard [('MISC', 'Hamilton')]
#
# ================================================================================
# TWEET 482
# TOKENS: Listen to 4 - Ayo Remix Rough by Yung 4 ( fooeee ) #np on #SoundCloud URL568
#
# Annotator A: [('MISC', '4 - Ayo'), ('MISC', 'Yung 4')]
# Annotator B: [('MISC', '4 - Ayo Remix Rough'), ('PER', 'Yung 4')]
# Annotator C: [('MISC', 'Ayo Remix Rough'), ('PER', 'Yung')]
# Baseline: [('MISC', '4'), ('PER', 'Ayo'), ('PER', 'Yung 4')]
# Bertweet: [('MISC', '4 -'), ('MISC', 'Ayo Remix'), ('PER', 'Yung 4')]
# Gold standard [('MISC', 'Ayo Remix Rough'), ('PER', 'Yung 4')]
#
# ================================================================================
# TWEET 484
# TOKENS: RT @USER2035 : JaDine Day . DNP 's First Day Gross . This Time 's First Day Gross 15 . 15M . 15M . All with 15 💜 Ang saya ulitin . 😹 #ThisTi …
#
# Annotator A: [('MISC', 'JaDine Day'), ('ORG', 'DNP')]
# Annotator B: []
# Annotator C: []
# Baseline: [('MISC', 'JaDine'), ('ORG', 'DNP'), ('MISC', 'Time')]
# Bertweet: []
# Gold standard [('MISC', 'JaDine Day'), ('MISC', 'DNP'), ('PER', 'Ang saya')]
#
# ================================================================================
# TWEET 485
# TOKENS: RT @USER1377 : Can we give respectability to those who want to break India ? Arun Jaitley in Rajya Sabha #AfzalDebate URL595
#
# Annotator A: [('LOC', 'India'), ('PER', 'Arun Jaitley'), ('MISC', 'Rajya Sabha')]
# Annotator B: [('ORG', 'India'), ('PER', 'Arun Jaitley'), ('PER', 'Rajya Sabha')]
# Annotator C: [('LOC', 'India'), ('PER', 'Arun Jaitley'), ('LOC', 'Rajya Sabha')]
# Baseline: [('LOC', 'India'), ('PER', 'Arun Jaitley'), ('MISC', 'Sabha')]
# Bertweet: [('LOC', 'India'), ('PER', 'Arun Jaitley'), ('LOC', 'Rajya Sabha')]
# Gold standard [('LOC', 'India'), ('PER', 'Arun Jaitley')]
#
# ================================================================================
# TWEET 486
# TOKENS: RT @USER785 : Hi from us @USER1759 ( excuse the insta spam ) URL980
#
# Annotator A: []
# Annotator B: [('ORG', 'insta')]
# Annotator C: []
# Baseline: []
# Bertweet: []
# Gold standard [('ORG', 'insta')]
#
# ================================================================================
# TWEET 489
# TOKENS: Rattled Bangladesh run into resurgent India #IndiavsBangladesh ... #IndiavsBangladesh URL1115
#
# Annotator A: [('LOC', 'Bangladesh'), ('LOC', 'India')]
# Annotator B: [('LOC', 'Bangladesh'), ('LOC', 'India')]
# Annotator C: [('LOC', 'Bangladesh'), ('LOC', 'resurgent'), ('LOC', 'India')]
# Baseline: [('LOC', 'Bangladesh'), ('LOC', 'India')]
# Bertweet: [('ORG', 'Bangladesh'), ('ORG', 'India')]
# Gold standard [('LOC', 'Bangladesh'), ('LOC', 'India')]
#
# ================================================================================
# TWEET 491
# TOKENS: Although your friendly nature usually puts others at ease , muc ... More for Libra URL430
#
# Annotator A: [('MISC', 'Libra')]
# Annotator B: [('ORG', 'Libra')]
# Annotator C: []
# Baseline: []
# Bertweet: [('MISC', 'Libra')]
# Gold standard [('MISC', 'Libra')]
#
# ================================================================================
# TWEET 494
# TOKENS: #Mention Brett McDanel Art @USER2221 #bizitalk #uniqueart URL1345 #business
#
# Annotator A: [('PER', 'Brett McDanel')]
# Annotator B: [('PER', 'Brett McDanel Art')]
# Annotator C: [('PER', 'Brett McDanel')]
# Baseline: [('PER', 'Brett McDanel')]
# Bertweet: [('PER', 'Brett McDanel')]
# Gold standard [('PER', 'Brett McDanel')]
#
# [6, 7, 11, 12, 15, 18, 19, 20, 22, 23, 24, 26, 27, 28, 43, 50, 54, 61, 66, 68, 81, 84, 85, 90, 91, 94, 95, 96, 98, 99, 100, 106, 107, 111, 112, 117, 118, 125, 130, 132, 133, 137, 144, 146, 148, 153, 154, 166, 168, 175, 181, 185, 187, 190, 195, 197, 199, 203, 204, 205, 208, 212, 220, 221, 228, 230, 234, 235, 240, 241, 243, 247, 250, 252, 255, 256, 257, 263, 267, 268, 269, 271, 273, 283, 284, 287, 291, 293, 299, 300, 306, 309, 312, 321, 322, 324, 329, 330, 333, 342, 344, 346, 347, 353, 354, 357, 360, 361, 365, 369, 372, 378, 385, 391, 394, 398, 400, 402, 403, 404, 405, 407, 410, 412, 422, 423, 425, 426, 428, 429, 430, 438, 443, 449, 453, 455, 460, 462, 467, 468, 471, 472, 474, 476, 478, 479, 481, 482, 484, 485, 486, 489, 491, 494]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
counts = [0 for _ in range(5)]

labels = ["LOC", "MISC", "ORG", "PER", "O"]
label2id = {l: i for i, l in enumerate(labels)}

# rows = gold, cols = predicted
token_labels = [[0 for _ in labels] for _ in labels]

def strip_bio(tag):
    if tag == "O":
        return "O"
    return tag.split("-")[1]

base = load("test_pred_base.jsonl")
base = [base[i] for i in range(len(base)) if i in disagree]

gold = load("test.jsonl")
gold = [gold[i] for i in range(len(gold)) if i in disagree]

for pred_ex, gold_ex in zip(base, gold):

    pred_tags = pred_ex["tags"]
    gold_tags = gold_ex["tags"]

    for P, G in zip(pred_tags, gold_tags):

        pred_label = strip_bio(id2label[P])
        gold_label = strip_bio(id2label[G])

        pred_idx = label2id[pred_label]
        gold_idx = label2id[gold_label]
        counts[gold_idx] += 1

        token_labels[gold_idx][pred_idx] += 1


for i in range(len(token_labels)):
    for j in range(len(token_labels)):
        token_labels[i][j]/= counts[i]
        token_labels[i][j]*=100
        token_labels[i][j] = round(token_labels[i][j],2)
df = pd.DataFrame(
    token_labels,
    index=labels, 
    columns=labels    
)
print(df)
print(counts)
plt.figure(figsize=(6, 5))

sns.heatmap(
    df,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    square=True
)

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Baseline Confusion Matrix")

plt.tight_layout()
plt.savefig("baseline.png")
plt.show()
# Out:
#         LOC   MISC    ORG    PER      O
# LOC   64.15   9.43   9.43   1.89  15.09
# MISC   2.52  41.18   5.04   1.68  49.58
# ORG    2.20  18.68  49.45   2.20  27.47
# PER    0.94   3.77   2.83  82.08  10.38
# O      0.21   1.05   0.59   0.38  97.78
# [53, 119, 91, 106, 2383]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
counts = [0 for _ in range(5)]

labels = ["LOC", "MISC", "ORG", "PER", "O"]
label2id = {l: i for i, l in enumerate(labels)}

# rows = gold, cols = predicted
token_labels = [[0 for _ in labels] for _ in labels]

def strip_bio(tag):
    if tag == "O":
        return "O"
    return tag.split("-")[1]

base = load("test_pred_base.jsonl")
base = [base[i] for i in range(len(base)) if i in disagree]

gold = load("test.jsonl")
gold = [gold[i] for i in range(len(gold)) if i in disagree]

for pred_ex, gold_ex in zip(base, gold):

    pred_tags = pred_ex["tags"]
    gold_tags = gold_ex["tags"]

    for P, G in zip(pred_tags, gold_tags):

        pred_label = strip_bio(id2label[P])
        gold_label = strip_bio(id2label[G])

        pred_idx = label2id[pred_label]
        gold_idx = label2id[gold_label]
        counts[gold_idx] += 1

        token_labels[gold_idx][pred_idx] += 1


for i in range(len(token_labels)):
    for j in range(len(token_labels)):
        token_labels[i][j]/= counts[i]
        token_labels[i][j]*=100
        token_labels[i][j] = round(token_labels[i][j],2)
df = pd.DataFrame(
    token_labels,
    index=labels, 
    columns=labels    
)
print(df)
print(counts)
plt.figure(figsize=(6, 5))

sns.heatmap(
    df,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    square=True
)

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Bertweet Confusion Matrix")

plt.tight_layout()
plt.savefig("bertweet.png")
plt.show()
# Out:
#         LOC   MISC    ORG    PER      O
# LOC   76.88   5.00   7.50   0.62  10.00
# MISC   0.80  60.80   3.47   5.33  29.60
# ORG    4.68   7.23  64.68   5.53  17.87
# PER    0.24   1.69   0.48  92.74   4.84
# O      0.07   0.22   0.13   0.13  99.44
# [160, 375, 235, 413, 17912]

# %%
def count_disagreements(a1, a2, a3):
    A = load(a1)
    B = load(a2)
    C = load(a3)

    total_tweets = len(A)
    disagree_tweets = 0
    total_tokens = 0
    tokens_labeled_by_someone = 0
    token_disagreements = 0

    for x, y, z in zip(A, B, C):
        spansA = extract_spans(x["tokens"], x["tags"])
        spansB = extract_spans(y["tokens"], y["tags"])
        spansC = extract_spans(z["tokens"], z["tags"])

        # Count tokens
        total_tokens += len(x["tokens"])

        # Count tokens where at least one annotator labeled something ≠ O (8)
        for tA, tB, tC in zip(x["tags"], y["tags"], z["tags"]):
            if not (tA == 8 and tB == 8 and tC == 8):
                tokens_labeled_by_someone += 1

        # Tweet-level disagreement
        if not (spansA == spansB == spansC):
            disagree_tweets += 1

            # Token-level disagreement count
            for tA, tB, tC in zip(x["tags"], y["tags"], z["tags"]):
                if not (tA == tB == tC):
                    token_disagreements += 1

    print("=== DISAGREEMENT SUMMARY ===")
    print(f"Total tweets: {total_tweets}")
    print(f"Tweets with disagreement: {disagree_tweets}")
    print(f"Tweets with full agreement: {total_tweets - disagree_tweets}")
    print()

    print(f"Tokens labeled by at least one annotator: {tokens_labeled_by_someone}")
    print(f"Total tokens: {total_tokens}")
    print()

    print(f"Tokens with disagreement: {token_disagreements}")
    print(f"Agreement rate (tokens): {(1 - token_disagreements/total_tokens):.4f}")
    print(f"Disagreement rate (tokens): {(token_disagreements/total_tokens):.4f}")

# Example usage:
count_disagreements("val_500.jsonl", "Hjalte_500.jsonl", "mar_500.jsonl")
# Out:
# === DISAGREEMENT SUMMARY ===
# Total tweets: 500
# Tweets with disagreement: 154
# Tweets with full agreement: 346
#
# Tokens labeled by at least one annotator: 545
# Total tokens: 7658
#
# Tokens with disagreement: 361
# Agreement rate (tokens): 0.9529
# Disagreement rate (tokens): 0.0471
